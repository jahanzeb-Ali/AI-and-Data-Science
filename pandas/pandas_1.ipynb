# %% [markdown]
# # Pandas

# %% [markdown]
# pandas working on both types of data numerical and categorical

# %% [markdown]
# ### pandas have two data types

# %% [markdown]
# ### 1) pandas Series object (Series)

# %% [markdown]
# #### A Series is a one-dimensional array-like object containing a sequence of values

# %%
import pandas as pd

# %%
s1 = pd.Series([1,2,34,21,12131,33,12])
s1
# Out:
# 0        1
# 1        2
# 2       34
# 3       21
# 4    12131
# 5       33
# 6       12
# dtype: int64

# %% [raw]
# Indexing in Series

# %%
s2 = pd.Series([1,2,34,21,12131,33,12], 
               index=["ali", "jahanzeb","imran", "Irfan", "kashif", "kamran", "saqib"]) 
s2
# Out:
# ali             1
# jahanzeb        2
# imran          34
# Irfan          21
# kashif      12131
# kamran         33
# saqib          12
# dtype: int64

# %%
s2.values
# Out:
# array([    1,     2,    34,    21, 12131,    33,    12])

# %%
s2.index
# Out:
# Index(['ali', 'jahanzeb', 'imran', 'Irfan', 'kashif', 'kamran', 'saqib'], dtype='object')

# %%
s2["imran"]
# Out:
# np.int64(34)

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
obj_series = pd.Series(sdata)
obj_series
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %% [markdown]
# ### 2) pandas Data Frame object (DataFrame)

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
df = pd.read_excel("employee_data.xlsx")

# %%
df.head()
# Out:
#   First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0     Aditi     Mishra  Female   35   80000        65000    15000
# 1       Sona     Singh  Female   35   70000        58000    12000
# 2       Devi    Thakur  Female   36   65000        60000     5000
# 3     Anjali      Kaur  Female   42   62000        50000    12000
# 4      Sahil  Deshmukh    Male   29   62000        57000     5000
#
#    Expenditure Percentage  Savings Percentage
# 0                0.812500            0.187500
# 1                0.828571            0.171429
# 2                0.923077            0.076923
# 3                0.806452            0.193548
# 4                0.919355            0.080645

# %%
df.shape
# Out:
# (35, 9)

# %%
df.size
# Out:
# 315

# %%
df.tail()
# Out:
#    First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 30      Shaan    Pandey    Male   37   25200        22000     3200
# 31      Navi      Gupta  Female   51   25000        20000     5000
# 32      Ambar    Khatri    Male   36   25000        22000     3000
# 33      Lata    Agarwal  Female   28   25000        24000     1000
# 34      Anaya   Agarwal  Female   25   24100        21000     3100
#
#     Expenditure Percentage  Savings Percentage
# 30                0.873016            0.126984
# 31                0.800000            0.200000
# 32                0.880000            0.120000
# 33                0.960000            0.040000
# 34                0.871369            0.128631

# %%
df.sample(5)
# Out:
#    First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 16        Nil     Kumar    Male   44   42000        38000     4000
# 3      Anjali      Kaur  Female   42   62000        50000    12000
# 25     Shaila     Gupta  Female   51   35000        34000     1000
# 15    Jasleen      Kaur  Female   50   45000        40000     5000
# 13      Kanak     Patel    Male   45   50500        40000    10500
#
#     Expenditure Percentage  Savings Percentage
# 16                0.904762            0.095238
# 3                 0.806452            0.193548
# 25                0.971429            0.028571
# 15                0.888889            0.111111
# 13                0.792079            0.207921

# %%
df["First Name"].notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# Name: First Name, dtype: bool

# %%
df[[ "Age","First Name","Salary"]]
# Out:
#     Age First Name  Salary
# 0    35     Aditi    80000
# 1    35       Sona   70000
# 2    36       Devi   65000
# 3    42     Anjali   62000
# 4    29      Sahil   62000
# 5    42     Adhira   62000
# 6    42      Divya   52500
# 7    52       Amar   52100
# 8    28       Jaya   52000
# 9    35      Candy   52000
# 10   35     Sudhir   52000
# 11   28     Raghav   51000
# 12   36    Amitabh   51000
# 13   45      Kanak   50500
# 14   40      Tulsi   45200
# 15   50    Jasleen   45000
# 16   44        Nil   42000
# 17   28      Anand   42000
# 18   29    Atharva   41000
# 19   26      Charu   40000
# 20   35       Ajay   36000
# 21   36        Jai   35500
# 22   35    Ishaan    35000
# 23   42     Dhruva   35000
# 24   31      Artha   35000
# 25   51     Shaila   35000
# 26   52      Inaya   30000
# 27   41      Darsh   30000
# 28   30      Mihir   30000
# 29   50    Agastya   25500
# 30   37      Shaan   25200
# 31   51      Navi    25000
# 32   36      Ambar   25000
# ...

# %%
df.
# Out:
# 0     80000
# 1     70000
# 2     65000
# 3     62000
# 4     62000
# 5     62000
# 6     52500
# 7     52100
# 8     52000
# 9     52000
# 10    52000
# 11    51000
# 12    51000
# 13    50500
# 14    45200
# 15    45000
# 16    42000
# 17    42000
# 18    41000
# 19    40000
# 20    36000
# 21    35500
# 22    35000
# 23    35000
# 24    35000
# 25    35000
# 26    30000
# 27    30000
# 28    30000
# 29    25500
# 30    25200
# 31    25000
# 32    25000
# 33    25000
# 34    24100
# Name: Salary, dtype: int64

# %%
df.Salary.min()
# Out:
# 24100

# %%
df["tax%"] = df.Salary.apply(lambda x: 20 if x>=50000 else 15 if x>=40000 else 10)

# %%
df
# Out:
#    First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0      Aditi     Mishra  Female   35   80000        65000    15000
# 1        Sona     Singh  Female   35   70000        58000    12000
# 2        Devi    Thakur  Female   36   65000        60000     5000
# 3      Anjali      Kaur  Female   42   62000        50000    12000
# 4       Sahil  Deshmukh    Male   29   62000        57000     5000
# 5      Adhira       Das    Male   42   62000        59000     3000
# 6       Divya     Bhatt  Female   42   52500        47000     5500
# 7        Amar       Rao    Male   52   52100        46000     6100
# 8        Jaya     Mehta  Female   28   52000        46000     6000
# 9       Candy     Patel  Female   35   52000        40000    12000
# 10     Sudhir    Mishra    Male   35   52000        47000     5000
# 11     Raghav     Verma    Male   28   51000        49000     2000
# 12    Amitabh     Joshi    Male   36   51000        50000     1000
# ...

# %%
df["tax_amount"] = df.Salary.apply(lambda x: x * 0.2 if x>=50000 else x*0.15 if x>=40000 else x*0.1)

# %%
df
# Out:
#    First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0      Aditi     Mishra  Female   35   80000        65000    15000
# 1        Sona     Singh  Female   35   70000        58000    12000
# 2        Devi    Thakur  Female   36   65000        60000     5000
# 3      Anjali      Kaur  Female   42   62000        50000    12000
# 4       Sahil  Deshmukh    Male   29   62000        57000     5000
# 5      Adhira       Das    Male   42   62000        59000     3000
# 6       Divya     Bhatt  Female   42   52500        47000     5500
# 7        Amar       Rao    Male   52   52100        46000     6100
# 8        Jaya     Mehta  Female   28   52000        46000     6000
# 9       Candy     Patel  Female   35   52000        40000    12000
# 10     Sudhir    Mishra    Male   35   52000        47000     5000
# 11     Raghav     Verma    Male   28   51000        49000     2000
# 12    Amitabh     Joshi    Male   36   51000        50000     1000
# ...

# %%
df.drop(columns=["tax"])
# Out:
#    First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0      Aditi     Mishra  Female   35   80000        65000    15000
# 1        Sona     Singh  Female   35   70000        58000    12000
# 2        Devi    Thakur  Female   36   65000        60000     5000
# 3      Anjali      Kaur  Female   42   62000        50000    12000
# 4       Sahil  Deshmukh    Male   29   62000        57000     5000
# 5      Adhira       Das    Male   42   62000        59000     3000
# 6       Divya     Bhatt  Female   42   52500        47000     5500
# 7        Amar       Rao    Male   52   52100        46000     6100
# 8        Jaya     Mehta  Female   28   52000        46000     6000
# 9       Candy     Patel  Female   35   52000        40000    12000
# 10     Sudhir    Mishra    Male   35   52000        47000     5000
# 11     Raghav     Verma    Male   28   51000        49000     2000
# 12    Amitabh     Joshi    Male   36   51000        50000     1000
# ...

# %%
# df["Net Salary "] = df.Salary.apply(lambda x: x - (x * 0.2) if x>=50000 else x - (x*0.15) if x>=40000 else x - (x*0.1))

df["Net Salary "] = df["Salary"] - df["tax_amount"]

# %%
df
# Out:
#    First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0      Aditi     Mishra  Female   35   80000        65000    15000
# 1        Sona     Singh  Female   35   70000        58000    12000
# 2        Devi    Thakur  Female   36   65000        60000     5000
# 3      Anjali      Kaur  Female   42   62000        50000    12000
# 4       Sahil  Deshmukh    Male   29   62000        57000     5000
# 5      Adhira       Das    Male   42   62000        59000     3000
# 6       Divya     Bhatt  Female   42   52500        47000     5500
# 7        Amar       Rao    Male   52   52100        46000     6100
# 8        Jaya     Mehta  Female   28   52000        46000     6000
# 9       Candy     Patel  Female   35   52000        40000    12000
# 10     Sudhir    Mishra    Male   35   52000        47000     5000
# 11     Raghav     Verma    Male   28   51000        49000     2000
# 12    Amitabh     Joshi    Male   36   51000        50000     1000
# ...
