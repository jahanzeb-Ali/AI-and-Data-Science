# %% [markdown]
# # Data Transformation

# %%
import pandas as pd

# %%
data = pd.read_csv("employees.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Employee_ID       101 non-null    object
#  1   Name              100 non-null    object
#  2   Department        101 non-null    object
#  3   Salary            100 non-null    float64
#  4   Experience_Years  98 non-null     float64
#  5   Join_Date         101 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 4.9+ KB

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# Length: 101, dtype: bool

# %%
data.drop_duplicates(subset=["Employee_ID"], inplace=True)

# %%
data.isna().sum()
# Out:
# Employee_ID         0
# Name                1
# Department          0
# Salary              1
# Experience_Years    2
# Join_Date           0
# dtype: int64

# %%
data.Name.dropna(axis=0,inplace=True)

# %%
data.dropna(inplace=True)

# %%
data.Name.isna().sum()
# Out:
# np.int64(0)

# %%
data.Department.unique()
# Out:
# array(['IT', 'HR', 'Finance', 'Marketing', 'finance', 'Sales'],
#       dtype=object)

# %%
data.Department.value_counts()
# Out:
# Department
# IT           33
# Finance      22
# HR           20
# Marketing    15
# Sales         5
# finance       1
# Name: count, dtype: int64

# %%
data.Department.replace("finance","Finance", inplace=True)
# Out:
# /tmp/ipykernel_4836/357045731.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.Department.replace("finance","Finance", inplace=True)

# %%
data.Department.unique()
# Out:
# array(['IT', 'HR', 'Finance', 'Marketing', 'Sales'], dtype=object)

# %%
data.Department.isna().sum()
# Out:
# np.int64(0)

# %%
data.Salary.unique()
# Out:
# array([  55000.,   48000.,   62000.,   45000.,   60000.,   47000.,
#          52000., 9999999.,   43000.,   58000.,   42000.,   61000.,
#          54000.,   51000.,   57000.])

# %%
data.Salary.fillna(data.Salary.median(), inplace=True)
# Out:
# /tmp/ipykernel_4836/4062971825.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.Salary.fillna(data.Salary.median(), inplace=True)

# %%
import matplotlib.pyplot as py

# %%
py.boxplot(data.Experience_Years)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7359f559f610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7359f559f890>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7359f559f4d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7359f559fb10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7359f559fc50>],
#  'means': []}

# %%
data.isna().sum()
# Out:
# Employee_ID         0
# Name                0
# Department          0
# Salary              0
# Experience_Years    0
# Join_Date           0
# dtype: int64

# %%
data.Salary.unique()

# %%
# data.loc[data.Salary > data.Salary.median(), "Salary"] == data.Salary.median()
data.Salary.mode()
# Out:
# 0    47000.0
# Name: Salary, dtype: float64

# %%
data.Salary.unique()
# Out:
# array([  55000.,   48000.,   62000.,   45000.,   60000.,   47000.,
#          52000., 9999999.,   43000.,   58000.,   42000.,   61000.,
#          54000.,   51000.,   57000.])

# %%
import pandas as pd
s = pd.Series(['cat', 'cow', 'dog', "lion", "wolf", "elephant","monkey", "lion", "wolf",'cat', 'cow'], index=index_map)
print("Series:\n", s)
# Out:
# Series:
#  pet          cat
# pet          cow
# pet          dog
# wild        lion
# wild        wolf
# wild    elephant
# wild      monkey
# wild        lion
# wild        wolf
# pet          cat
# pet          cow
# dtype: object

# %%
print("Mapping: ")
index_map=s.map({'cat': 'pet', 
       'cow': 'pet',
       "dog":"pet",
       "lion":"wild",
       "monkey":"wild",
       "wolf": "wild",
        "elephant":"wild"})
# Out:
# Mapping:
