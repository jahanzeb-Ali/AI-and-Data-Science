# %%
import pandas as pd

# %%
emp = pd.read_excel("employee_data.xlsx")

# %%
emp
# Out:
#    First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0      Aditi     Mishra  Female   35   80000        65000    15000
# 1        Sona     Singh  Female   35   70000        58000    12000
# 2        Devi    Thakur  Female   36   65000        60000     5000
# 3      Anjali      Kaur  Female   42   62000        50000    12000
# 4       Sahil  Deshmukh    Male   29   62000        57000     5000
# 5      Adhira       Das    Male   42   62000        59000     3000
# 6       Divya     Bhatt  Female   42   52500        47000     5500
# 7        Amar       Rao    Male   52   52100        46000     6100
# 8        Jaya     Mehta  Female   28   52000        46000     6000
# 9       Candy     Patel  Female   35   52000        40000    12000
# 10     Sudhir    Mishra    Male   35   52000        47000     5000
# 11     Raghav     Verma    Male   28   51000        49000     2000
# 12    Amitabh     Joshi    Male   36   51000        50000     1000
# ...

# %%
emp.iloc[:5,2:6]
# Out:
#    Gender  Age  Salary  Expenditure
# 0  Female   35   80000        65000
# 1  Female   35   70000        58000
# 2  Female   36   65000        60000
# 3  Female   42   62000        50000
# 4    Male   29   62000        57000

# %%
emp.loc[:5,"First Name" : "Savings"]
# Out:
#   First Name Last Name  Gender  Age  Salary  Expenditure  Savings
# 0     Aditi     Mishra  Female   35   80000        65000    15000
# 1       Sona     Singh  Female   35   70000        58000    12000
# 2       Devi    Thakur  Female   36   65000        60000     5000
# 3     Anjali      Kaur  Female   42   62000        50000    12000
# 4      Sahil  Deshmukh    Male   29   62000        57000     5000
# 5     Adhira       Das    Male   42   62000        59000     3000

# %%
emp.Gender == "Female"
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6      True
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26     True
# 27    False
# 28    False
# 29    False
# 30    False
# 31     True
# 32    False
# 33     True
# 34     True
# Name: Gender, dtype: bool

# %%
emp[(emp.Gender == "Female") & (emp.Age >= 30) & (emp.Salary <= 30000 )]
emp.head()
# Out:
#   First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0     Aditi     Mishra  Female   35   80000        65000    15000
# 1       Sona     Singh  Female   35   70000        58000    12000
# 2       Devi    Thakur  Female   36   65000        60000     5000
# 3     Anjali      Kaur  Female   42   62000        50000    12000
# 4      Sahil  Deshmukh    Male   29   62000        57000     5000
#
#    Expenditure Percentage  Savings Percentage
# 0                0.812500            0.187500
# 1                0.828571            0.171429
# 2                0.923077            0.076923
# 3                0.806452            0.193548
# 4                0.919355            0.080645

# %%
emp[(emp["Savings"] + emp["Expenditure"]) >= 52000][["First Name","Last Name","Age","Salary"]]
# Out:
#    First Name Last Name  Age  Salary
# 0      Aditi     Mishra   35   80000
# 1        Sona     Singh   35   70000
# 2        Devi    Thakur   36   65000
# 3      Anjali      Kaur   42   62000
# 4       Sahil  Deshmukh   29   62000
# 5      Adhira       Das   42   62000
# 6       Divya     Bhatt   42   52500
# 7        Amar       Rao   52   52100
# 8        Jaya     Mehta   28   52000
# 9       Candy     Patel   35   52000
# 10     Sudhir    Mishra   35   52000
