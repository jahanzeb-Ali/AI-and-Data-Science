# %%
import pandas as pd

# %%
data = pd.read_excel("employee_data.xlsx")

# %%
data.head()
# Out:
#   First Name Last Name  Gender  Age  Salary  Expenditure  Savings  \
# 0     Aditi     Mishra  Female   35   80000        65000    15000
# 1       Sona     Singh  Female   35   70000        58000    12000
# 2       Devi    Thakur  Female   36   65000        60000     5000
# 3     Anjali      Kaur  Female   42   62000        50000    12000
# 4      Sahil  Deshmukh    Male   29   62000        57000     5000
#
#    Expenditure Percentage  Savings Percentage
# 0                0.812500            0.187500
# 1                0.828571            0.171429
# 2                0.923077            0.076923
# 3                0.806452            0.193548
# 4                0.919355            0.080645

# %%
data[(data["Salary"] > data["Salary"].mean()) & (data["Gender"] == "Male")]
# Out:
#    First Name Last Name Gender  Age  Salary  Expenditure  Savings  \
# 4       Sahil  Deshmukh   Male   29   62000        57000     5000
# 5      Adhira       Das   Male   42   62000        59000     3000
# 7        Amar       Rao   Male   52   52100        46000     6100
# 10     Sudhir    Mishra   Male   35   52000        47000     5000
# 11     Raghav     Verma   Male   28   51000        49000     2000
# 12    Amitabh     Joshi   Male   36   51000        50000     1000
# 13      Kanak     Patel   Male   45   50500        40000    10500
#
#     Expenditure Percentage  Savings Percentage
# 4                 0.919355            0.080645
# 5                 0.951613            0.048387
# 7                 0.882917            0.117083
# 10                0.903846            0.096154
# 11                0.960784            0.039216
# 12                0.980392            0.019608
# 13                0.792079            0.207921

# %%
ins_data = pd.read_csv("insurance.csv")

# %%
ins_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
ins_data.shape
# Out:
# (1338, 7)

# %%
ins_data[(ins_data["sex"] == "female")& (ins_data["smoker"] == "yes")&(ins_data["region"] == "southwest")& (ins_data["age"] < 30 )]
# Out:
#       age     sex   bmi  children smoker     region      charges
# 0      19  female  27.9         0    yes  southwest  16884.92400
# 126    19  female  28.3         0    yes  southwest  17081.08000
# 314    27  female  31.4         0    yes  southwest  34838.87300
# 362    19  female  21.7         0    yes  southwest  13844.50600
# 1120   23  female  31.4         0    yes  southwest  34166.27300
# 1231   20  female  21.8         0    yes  southwest  20167.33603
# 1308   25  female  30.2         0    yes  southwest  33900.65300
# 1313   19  female  34.7         2    yes  southwest  36397.57600

# %%
ins_data.sex.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
ins_data.sex.value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
ins_data.smoker.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
smokers_freq = ins_data.smoker.value_counts()

# %%
import matplotlib.pyplot as pl

# %%
pl.bar(x=smokers_freq.index, height = smokers_freq.values)
# Out:
# <BarContainer object of 2 artists>

# %%
movies = pd.read_csv("movies.csv")

# %%
movies.shape
# Out:
# (970, 16)

# %%
movies.head()
# Out:
#                                        Movie   LeadStudio  RottenTomatoes  \
# 0                               Spider-Man 3         Sony            61.0
# 1                            Shrek the Third    Paramount            42.0
# 2                               Transformers    Paramount            57.0
# 3   Pirates of the Caribbean: At World's End       Disney            45.0
# 4  Harry Potter and the Order of the Phoenix  Warner Bros            78.0
#
#    AudienceScore          Story      Genre  TheatersOpenWeek  OpeningWeekend  \
# 0           54.0  Metamorphosis     Action            4252.0           151.1
# 1           57.0          Quest  Animation            4122.0           121.6
# 2           89.0  Monster Force     Action            4011.0            70.5
# 3           74.0         Rescue     Action            4362.0           114.7
# 4           82.0          Quest  Adventure            4285.0            77.1
#
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Movie             970 non-null    object
#  1   LeadStudio        961 non-null    object
#  2   RottenTomatoes    913 non-null    float64
#  3   AudienceScore     907 non-null    float64
#  4   Story             641 non-null    object
#  5   Genre             691 non-null    object
#  6   TheatersOpenWeek  949 non-null    float64
#  7   OpeningWeekend    969 non-null    float64
#  8   BOAvgOpenWeekend  945 non-null    float64
#  9   DomesticGross     970 non-null    float64
#  10  ForeignGross      876 non-null    float64
#  11  WorldGross        914 non-null    float64
#  12  Budget            897 non-null    float64
#  13  Profitability     896 non-null    float64
#  14  OpenProfit        895 non-null    float64
#  15  Year              970 non-null    int64
# ...

# %%
movies[movies.Budget == movies.Budget.max()]
# Out:
#                                       Movie LeadStudio  RottenTomatoes  \
# 3  Pirates of the Caribbean: At World's End     Disney            45.0
#
#    AudienceScore   Story   Genre  TheatersOpenWeek  OpeningWeekend  \
# 3           74.0  Rescue  Action            4362.0           114.7
#
#    BOAvgOpenWeekend  DomesticGross  ForeignGross  WorldGross  Budget  \
# 3           26302.0         309.42         654.0      963.42   300.0
#
#    Profitability  OpenProfit  Year
# 3         321.14       38.23  2007

# %%
movies[(movies.Genre == "Action") & (movies.Year >= 2005)]
# Out:
#                                         Movie   LeadStudio  RottenTomatoes  \
# 0                                Spider-Man 3         Sony            61.0
# 2                                Transformers    Paramount            57.0
# 3    Pirates of the Caribbean: At World's End       Disney            45.0
# 9                                         300  Warner Bros            60.0
# 15                                Rush Hour 3  Warner Bros            20.0
# ..                                        ...          ...             ...
# 823                                Iron Man 3  Buena Vista            78.0
# 825                        THG: Catching Fire    Lionsgate            90.0
# 828                          Fast & Furious 6    Universal            69.0
# 831                              Man of Steel  Warner Bros            55.0
# 886     The Mortal Instruments: City of Bones         Sony            12.0
#
# ...

# %%
movies.sort_values(by="Budget",ascending=False).head()
# Out:
#                                         Movie   LeadStudio  RottenTomatoes  \
# 3    Pirates of the Caribbean: At World's End       Disney            45.0
# 468                                   Tangled       Disney            89.0
# 0                                Spider-Man 3         Sony            61.0
# 710                               John Carter  Buena Vista            51.0
# 778                     The Dark Knight Rises  Warner Bros            88.0
#
#      AudienceScore          Story      Genre  TheatersOpenWeek  \
# 3             74.0         Rescue     Action            4362.0
# 468           88.0           Love  Animation            3603.0
# 0             54.0  Metamorphosis     Action            4252.0
# 710           60.0            NaN        NaN            3749.0
# 778           90.0            NaN        NaN            4404.0
#
#      OpeningWeekend  BOAvgOpenWeekend  DomesticGross  ForeignGross  \
# ...

# %%
movies.sort_values(by="Budget",ascending=False).tail()
# Out:
#                       Movie              LeadStudio  RottenTomatoes  \
# 957                      No                    Sony            93.0
# 962                  Wadjda                    Sony            99.0
# 963  Much Ado About Nothing    Roadside Attractions            84.0
# 965             The Canyons                     IFC            22.0
# 967     The English Teacher  Cinedigm Entertainment            42.0
#
#      AudienceScore Story Genre  TheatersOpenWeek  OpeningWeekend  \
# 957           79.0   NaN   NaN              99.0            0.07
# 962           89.0   NaN   NaN              87.0            0.04
# 963           78.0   NaN   NaN             222.0            0.17
# 965            NaN   NaN   NaN               1.0            0.01
# 967            NaN   NaN   NaN               2.0            0.01
#
#      BOAvgOpenWeekend  DomesticGross  ForeignGross  WorldGross  Budget  \
# 957             725.0           2.34           NaN        2.34     NaN
# ...

# %%
movies.isna().sum()
# Out:
# Movie                 0
# LeadStudio            9
# RottenTomatoes       57
# AudienceScore        63
# Story               329
# Genre               279
# TheatersOpenWeek     21
# OpeningWeekend        1
# BOAvgOpenWeekend     25
# DomesticGross         0
# ForeignGross         94
# WorldGross           56
# Budget               73
# Profitability        74
# OpenProfit           75
# Year                  0
# dtype: int64

# %%
movies = movies.drop(columns = ["Story","Genre"])

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Movie             970 non-null    object
#  1   LeadStudio        961 non-null    object
#  2   RottenTomatoes    913 non-null    float64
#  3   AudienceScore     907 non-null    float64
#  4   TheatersOpenWeek  949 non-null    float64
#  5   OpeningWeekend    969 non-null    float64
#  6   BOAvgOpenWeekend  945 non-null    float64
#  7   DomesticGross     970 non-null    float64
#  8   ForeignGross      876 non-null    float64
#  9   WorldGross        914 non-null    float64
#  10  Budget            897 non-null    float64
#  11  Profitability     896 non-null    float64
#  12  OpenProfit        895 non-null    float64
#  13  Year              970 non-null    int64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 106.2+ KB

# %%
movies.isna().sum()
# Out:
# Movie                0
# LeadStudio           9
# RottenTomatoes      57
# AudienceScore       63
# TheatersOpenWeek    21
# OpeningWeekend       1
# BOAvgOpenWeekend    25
# DomesticGross        0
# ForeignGross        94
# WorldGross          56
# Budget              73
# Profitability       74
# OpenProfit          75
# Year                 0
# dtype: int64

# %%
movies = movies.dropna()

# %%
movies.isna().sum()
# Out:
# Movie               0
# LeadStudio          0
# RottenTomatoes      0
# AudienceScore       0
# TheatersOpenWeek    0
# OpeningWeekend      0
# BOAvgOpenWeekend    0
# DomesticGross       0
# ForeignGross        0
# WorldGross          0
# Budget              0
# Profitability       0
# OpenProfit          0
# Year                0
# dtype: int64
