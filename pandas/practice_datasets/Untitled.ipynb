# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("by_claude.csv")

# %%
df = pd.read_csv("by_claude.csv", engine="python", on_bad_lines="skip")

# %%
df.head()
# Out:
#          Column 1                                         Column 2  \
# 0             NaN                                              NaN
# 1             NaN                                              NaN
# 2     Report For:  01-March-2026 00:00:00 - 31-March-2026 23:59:59
# 3  Total Distance                                              NaN
# 4      3496.77 Km                                              NaN
#
#             Column 3                                      Column 4 Column 5  \
# 0                NaN  Report Generated On Wednesday, 22-April-2026      NaN
# 1                NaN                               Movement Report      NaN
# 2                NaN                                           NaN      NaN
# 3  Total Fuel Burned                                           NaN      NaN
# 4         437.1 ltrs                                           NaN      NaN
#
#   Column 6 Column 7
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(4189)

# %%
df[df.duplicated]
# Out:
#          Column 1  Column 2    Column 3  \
# 8      3496.77 Km       NaN  437.1 ltrs
# 22            NaN       NaN         NaN
# 23            NaN       NaN         NaN
# 24     Start Date  Ignition       Speed
# 25       dd/mm/yy       NaN       Km/Hr
# ...           ...       ...         ...
# 13745         NaN       NaN         NaN
# 13746  Start Date  Ignition       Speed
# 13747    dd/mm/yy       NaN       Km/Hr
# 13749         NaN       NaN         NaN
# 13751         NaN       NaN         NaN
#
#                                            Column 4  Column 5   Column 6  \
# 8                                               NaN       NaN        NaN
# 22     Report Generated On Wednesday, 22-April-2026       NaN        NaN
# 23                                  Movement Report       NaN        NaN
# 24                                  Status Location  Latitude  Longitude
# 25                                              NaN       NaN        NaN
# ...

# %%
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
df = df.drop_duplicates()

# %%
df.head(10)
# Out:
#                Column 1                                         Column 2  \
# 0                   NaN                                              NaN
# 1                   NaN                                              NaN
# 2           Report For:  01-March-2026 00:00:00 - 31-March-2026 23:59:59
# 3        Total Distance                                              NaN
# 4            3496.77 Km                                              NaN
# 5     Vehicle # JF-7479                                              NaN
# 6  Engine # 1KD-2023876                                              NaN
# 7              Distance                                              NaN
# 8            3496.77 Km                                              NaN
# 9            Start Date                                         Ignition
#
#             Column 3                                      Column 4  Column 5  \
# 0                NaN  Report Generated On Wednesday, 22-April-2026       NaN
# ...

# %%
df = df.drop(df.index[7:])

# %%
df.columns = ["Ignition","Speed","Status","Location","Latitude","Longitude","Distance"]

# %%
df.head()
# Out:
#                Column 1  Column 2     Column 3  \
# 7              Distance       NaN  Fuel Burned
# 8            3496.77 Km       NaN   437.1 ltrs
# 9            Start Date  Ignition        Speed
# 10             dd/mm/yy       NaN        Km/Hr
# 11  01/03/2026 00:29 AM       OFF            0
#
#                                              Column 4    Column 5    Column 6  \
# 7                                                 NaN         NaN         NaN
# 8                                                 NaN         NaN         NaN
# 9                                     Status Location    Latitude   Longitude
# 10                                                NaN         NaN         NaN
# 11  Stop 0Km from Pipro Goth, Shah Town, Bin Qasim...  24.8545916  67.3337116
#
#     Column 7
# 7        NaN
# 8        NaN
# 9   Distance
# 10        km
# 11         0
